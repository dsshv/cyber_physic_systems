# %%
import numpy as np
import numpy.random as rand

# %%
rand.seed(50)
temperature_V1 = rand.randint(0, 5, 10000)
temperature_V2 = rand.randint(-3, 0, 10000)
diff = temperature_V1 - temperature_V2
diff
# Out:
# array([2, 3, 4, ..., 3, 5, 2])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(diff)
# Out:
# (array([ 665., 1286.,    0., 1933.,    0., 2044., 2029.,    0., 1356.,
#          687.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
#   Cell In [31], line 1
#     plt.
#         ^
# SyntaxError: invalid syntax
