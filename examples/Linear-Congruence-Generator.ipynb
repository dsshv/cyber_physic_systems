# %%
def LCG(N, S):
    a = 7**5
    M = 2**31-1
     
    def f(S):
        return (a*S)%M
    U = []
    
    for i in range (N):
        S = f(S)
        U+= [S/M]
    return U

# %%
LCG(1,23487)
# Out:
# [0.18381793479612932]

# %%
LCG(1,234871)
# Out:
# [0.8381871743305527]

# %%
LCG(1,23487173)
# Out:
# [0.8192887580112036]

# %%
LCG(1,23487173173737)
# Out:
# [0.11774111963703349]

# %%
RES = LCG(10**5, 177323712371)

# %%
RES
# Out:
# [0.8514676233061904,
#  0.6163449071423825,
#  0.9088543420233085,
#  0.11492638574676886,
#  0.5677652459441522,
#  0.4304885833666141,
#  0.2216206426832921,
#  0.778141578090443,
#  0.2255029660768355,
#  0.02835085337439126,
#  0.49279266339391126,
#  0.3662936614669364,
#  0.29756827480046466,
#  0.2299945714091857,
#  0.5187616741837755,
#  0.8274580067151496,
#  0.0867188615196938,
#  0.4839055614936657,
#  0.0007720240395385884,
#  0.9754080325250551,
#  0.682802648601496,
#  0.8641150453426479,
#  0.1815670738842185,
#  0.5978107720603285,
#  0.4056460179414814,
#  0.6926235424785985,
#  0.9238784378040016,
#  0.6249041718546786,
#  0.7644163615835907,
#  0.5457891354084896,
#  0.0779988104840735,
#  0.9260078058233521,
#  0.4131924730787019,
#  0.5258950337422523,
#  0.7178321060341932,
#  0.6042061166857398,
#  0.89220313722836,
#  0.2581273970464838,
#  0.3471621602527621,
#  0.7544273681726434,
#  0.6607768776178252,
#  0.6769821227886631,
#  0.038537709060375444,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(RES)
# Out:
# (array([ 9935., 10159.,  9933.,  9893., 10052.,  9982.,  9982.,  9890.,
#          9980., 10194.]),
#  array([3.79793346e-06, 1.00002878e-01, 2.00001959e-01, 3.00001039e-01,
#         4.00000120e-01, 4.99999200e-01, 5.99998281e-01, 6.99997361e-01,
#         7.99996442e-01, 8.99995522e-01, 9.99994603e-01]),
#  <BarContainer object of 10 artists>)

# %%
# !pip install matplotlib
